# %%
from os.path import join

from gensim.models import KeyedVectors
import pandas as pd
import numpy as np
import umap
import umap.plot
import hdbscan

import utilities

pd.set_option('display.max_rows', 500)

# %%
lexicon = utilities.get_arabic_lexicon_data()

# %%
emotions = list(lexicon.keys())
emotions
# Out:
# ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']

# %%
glf_embedding = KeyedVectors.load_word2vec_format(join("embeddings", "glf.vec"))
egy_embedding = KeyedVectors.load_word2vec_format(join("embeddings", "egy.vec"))
irq_embedding = KeyedVectors.load_word2vec_format(join("embeddings", "irq.vec"))
nor_embedding = KeyedVectors.load_word2vec_format(join("embeddings", "nor.vec"))
lev_embedding = KeyedVectors.load_word2vec_format(join("embeddings", "lev.vec"))

# %%
def generate_emotion_lexicon(embedding, emotion, min_cluster_size, num_words_to_generate=100, verbose=False, save=False, embedding_name=None):
    if save:
        assert embedding_name is not None, "embedding_name must not be None when trying to save" 
    
    lexicon = utilities.get_arabic_lexicon_data()
    def get(embedding, val, default=None):
        try:
            return embedding[val]
        except KeyError:
            return default

    emotions = list(lexicon.keys())
    if verbose:
        print(f"Emotions in lexicon {emotions}")
    assert emotion in lexicon, f"The emotion {emotion} is not in the Lexicon"

    vecs_non_filtered = list(map(lambda wrd: get(embedding, wrd, default=None), lexicon[emotion]))
    if verbose:
        print(f"Number of words considered {sum(1 for vec in vecs_non_filtered if vec is not None)}/{len(vecs_non_filtered)}")
    vecs = list(filter(lambda x: x is not None, vecs_non_filtered))
    centroid = np.mean(vecs, axis=0)

    clusterer = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size)
    cluster_labels = clusterer.fit_predict(vecs)

    if verbose:
        print(cluster_labels)
    cluster_to_words = {}
    for focus_cluster in np.unique(cluster_labels):
        clustered_vecs = [vec for cluster, vec in zip(cluster_labels, vecs) if cluster == focus_cluster]
        clustered_centroid = np.median(clustered_vecs, axis=0)
        cluster_to_words[focus_cluster] = list(zip(*embedding.similar_by_vector(clustered_centroid, num_words_to_generate)))[0]

    if verbose:
        mapper = umap.UMAP().fit(vecs)
        umap.plot.points(mapper, labels=cluster_labels)
    df = pd.DataFrame(cluster_to_words)
    style = df.style.applymap(lambda x: "background-color: rgba(20, 20, 20, 1)" if x in lexicon[emotion] else "")
    if save:
        df.to_csv(f"emotion_lexicon/{embedding_name}_{emotion}_minclustersize={min_cluster_size}.csv")
    return style

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem with using all words in generating similar words
# ### Solution: cluster the vector representation of words

# %%
df = generate_emotion_lexicon(embedding=glf_embedding, emotion="anger", min_cluster_size=100, num_words_to_generate=500)
df.data.iloc[:20]
# Out:
#         -1
# 0      لطخ
# 1    خبائث
# 2      طغا
# 3     بذيء
# 4   وماخفى
# 5       ذآ
# 6     اظمى
# 7     تلذذ
# 8     أشمط
# 9     جحود
# 10    هتلر
# 11      كخ
# 12   حينئذ
# 13       ى
# 14    معصم
# 15   جرثوم
# 16    كآبة
# 17       {
# 18   اضحوك
# 19     نكح

# %% [markdown]
# ### Problem with centroid idea
# ### Solution(?): Maybe decrease the min_cluster_size?
# ![img](https://www.researchgate.net/profile/Fotios-Katsilieris-2/publication/239926467/figure/fig4/AS:669426328301595@1536615082633/An-example-of-the-difference-between-a-convex-and-a-non-convex-region.ppm)

# %% [markdown]
# # Notes

# %% [markdown]
# ### finding the centroid with the mean seems to give worse performance than finding it with the median. Probably since the mean is swayed by outlier vectors

# %% [markdown]
# # Glf

# %%
df = generate_emotion_lexicon(embedding=glf_embedding, emotion="sadness", min_cluster_size=8, num_words_to_generate=100)
df
# Out:
# <style type="text/css">
# #T_35e53_row0_col1, #T_35e53_row0_col2, #T_35e53_row0_col3, #T_35e53_row0_col4, #T_35e53_row0_col5, #T_35e53_row0_col6, #T_35e53_row0_col7, #T_35e53_row0_col8, #T_35e53_row0_col9, #T_35e53_row2_col3, #T_35e53_row3_col6, #T_35e53_row5_col3, #T_35e53_row6_col1, #T_35e53_row6_col2, #T_35e53_row6_col6, #T_35e53_row9_col1, #T_35e53_row11_col2, #T_35e53_row12_col0, #T_35e53_row15_col0, #T_35e53_row15_col6, #T_35e53_row25_col1, #T_35e53_row27_col1, #T_35e53_row29_col8, #T_35e53_row30_col6, #T_35e53_row31_col0, #T_35e53_row31_col8, #T_35e53_row32_col8, #T_35e53_row42_col2, #T_35e53_row50_col6, #T_35e53_row52_col6, #T_35e53_row53_col6, #T_35e53_row54_col2, #T_35e53_row57_col0, #T_35e53_row57_col6, #T_35e53_row62_col3, #T_35e53_row62_col6, #T_35e53_row64_col9, #T_35e53_row68_col7, #T_35e53_row70_col1, #T_35e53_row71_col6, #T_35e53_row75_col6, #T_35e53_row76_col3, #T_35e53_row82_col5, #T_35e53_row92_col4, #T_35e53_row92_col8, #T_35e53_row98_col4 {
#   background-color: rgba(20, 20, 20, 1);
# }
# </style>
# <table id="T_35e53">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35e53_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_35e53_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_35e53_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_35e53_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_35e53_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_35e53_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_35e53_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_35e53_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_35e53_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_35e53_level0_col9" class="col_heading level0 col9" >8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35e53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35e53_row0_col0" class="data row0 col0" >طغا</td>
#       <td id="T_35e53_row0_col1" class="data row0 col1" >حزن</td>
#       <td id="T_35e53_row0_col2" class="data row0 col2" >ندم</td>
#       <td id="T_35e53_row0_col3" class="data row0 col3" >حزين</td>
#       <td id="T_35e53_row0_col4" class="data row0 col4" >نادم</td>
#       <td id="T_35e53_row0_col5" class="data row0 col5" >كئيب</td>
#       <td id="T_35e53_row0_col6" class="data row0 col6" >محزن</td>
#       <td id="T_35e53_row0_col7" class="data row0 col7" >أسى</td>
#       <td id="T_35e53_row0_col8" class="data row0 col8" >بؤس</td>
#       <td id="T_35e53_row0_col9" class="data row0 col9" >بائس</td>
#     </tr>
#     <tr>
#       <th id="T_35e53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35e53_row1_col0" class="data row1 col0" >لطخ</td>
#       <td id="T_35e53_row1_col1" class="data row1 col1" >نحزن</td>
#       <td id="T_35e53_row1_col2" class="data row1 col2" >اندم</td>
#       <td id="T_35e53_row1_col3" class="data row1 col3" >احزن</td>
#       <td id="T_35e53_row1_col4" class="data row1 col4" >نادره</td>
#       <td id="T_35e53_row1_col5" class="data row1 col5" >ثلج</td>
#       <td id="T_35e53_row1_col6" class="data row1 col6" >نحزن</td>
#       <td id="T_35e53_row1_col7" class="data row1 col7" >قسى</td>
#       <td id="T_35e53_row1_col8" class="data row1 col8" >لدغ</td>
#       <td id="T_35e53_row1_col9" class="data row1 col9" >ذقن</td>
#     </tr>
#     <tr>
#       <th id="T_35e53_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_35e53_row2_col0" class="data row2 col0" >خبائث</td>
#       <td id="T_35e53_row2_col1" class="data row2 col1" >أحزن</td>
#       <td id="T_35e53_row2_col2" class="data row2 col2" >ندمان</td>
#       <td id="T_35e53_row2_col3" class="data row2 col3" >مهموم</td>
#       <td id="T_35e53_row2_col4" class="data row2 col4" >نادى</td>
#       <td id="T_35e53_row2_col5" class="data row2 col5" >مزدحم</td>
#       <td id="T_35e53_row2_col6" class="data row2 col6" >أحزن</td>
#       <td id="T_35e53_row2_col7" class="data row2 col7" >أتناسى</td>
#       <td id="T_35e53_row2_col8" class="data row2 col8" >ذآ</td>
#       <td id="T_35e53_row2_col9" class="data row2 col9" >باض</td>
#     </tr>
#     <tr>
#       <th id="T_35e53_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35e53_row3_col0" class="data row3 col0" >أيقظ</td>
#       <td id="T_35e53_row3_col1" class="data row3 col1" >احزن</td>
#       <td id="T_35e53_row3_col2" class="data row3 col2" >أخسر</td>
#       <td id="T_35e53_row3_col3" class="data row3 col3" >حز</td>
#       <td id="T_35e53_row3_col4" class="data row3 col4" >ادم</td>
#       <td id="T_35e53_row3_col5" class="data row3 col5" >مثلج</td>
#       <td id="T_35e53_row3_col6" class="data row3 col6" >محزون</td>
#       <td id="T_35e53_row3_col7" class="data row3 col7" >ابنسى</td>
#       <td id="T_35e53_row3_col8" class="data row3 col8" >يغث</td>
#       <td id="T_35e53_row3_col9" class="data row3 col9" >بالى</td>
#     </tr>
#     <tr>
#       <th id="T_35e53_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35e53_row4_col0" class="data row4 col0" >يؤلمك</td>
#       <td id="T_35e53_row4_col1" class="data row4 col1" >لاتحزن</td>
#       <td id="T_35e53_row4_col2" class="data row4 col2" >تتعثر</td>
#       <td id="T_35e53_row4_col3" class="data row4 col3" >عآد</td>
#       <td id="T_35e53_row4_col4" class="data row4 col4" >نادية</td>
#       <td id="T_35e53_row4_col5" class="data row4 col5" >يغث</td>
#       <td id="T_35e53_row4_col6" class="data row4 col6" >مح</td>
#       <td id="T_35e53_row4_col7" class="data row4 col7" >أبنسى</td>
#       <td id="T_35e53_row4_col8" class="data row4 col8" >غطا</td>
#       <td id="T_35e53_row4_col9" class="data row4 col9" >كأنما</td>
#     </tr>
#     <tr>
#       <th id="T_35e53_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_35e53_row5_col0" class="data row5 col0" >ذآ</td>
#       <td id="T_35e53_row5_col1" class="data row5 col1" >أبكى</td>
#       <td id="T_35e53_row5_col2" class="data row5 col2" >رآضي</td>
#       <td id="T_35e53_row5_col3" class="data row5 col3" >حزن</td>
#       <td id="T_35e53_row5_col4" class="data row5 col4" >صادم</td>
#       <td id="T_35e53_row5_col5" class="data row5 col5" >كرهوني</td>
#       <td id="T_35e53_row5_col6" class="data row5 col6" >احزن</td>
#       <td id="T_35e53_row5_col7" class="data row5 col7" >يقسى</td>
#       <td id="T_35e53_row5_col8" class="data row5 col8" >خبائث</td>
#       <td id="T_35e53_row5_col9" class="data row5 col9" >أيقظ</td>
#     </tr>
#     <tr>
#       <th id="T_35e53_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_35e53_row6_col0" class="data row6 col0" >ى</td>
#       <td id="T_35e53_row6_col1" class="data row6 col1" >حزين</td>
#       <td id="T_35e53_row6_col2" class="data row6 col2" >مكسور</td>
#       <td id="T_35e53_row6_col3" class="data row6 col3" >أنين</td>
#       <td id="T_35e53_row6_col4" class="data row6 col4" >ناصب</td>
#       <td id="T_35e53_row6_col5" class="data row6 col5" >ماونتنز</td>
#       <td id="T_35e53_row6_col6" class="data row6 col6" >حزن</td>
#       <td id="T_35e53_row6_col7" class="data row6 col7" >تقسى</td>
#       <td id="T_35e53_row6_col8" class="data row6 col8" >أنهب</td>
#       <td id="T_35e53_row6_col9" class="data row6 col9" >أشمط</td>
#     </tr>
#     <tr>
#       <th id="T_35e53_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_35e53_row7_col0" class="data row7 col0" >حينئذ</td>
#       <td id="T_35e53_row7_col1" class="data row7 col1" >عزف</td>
#       <td id="T_35e53_row7_col2" class="data row7 col2" >تيأسي</td>
#       <td id="T_35e53_row7_col3" class="data row7 col3" >غمضة</td>
#       <td id="T_35e53_row7_col4" class="data row7 col4" >ناصع</td>
#       <td id="T_35e53_row7_col5" class="data row7 col5" >يتمشون</td>
#       <td id="T_35e53_row7_col6" class="data row7 col6" >محك</td>
#       <td id="T_35e53_row7_col7" class="data row7 col7" >أقسى</td>
#       <td id="T_35e53_row7_col8" class="data row7 col8" >غث</td>
#       <td id="T_35e53_row7_col9" class="data row7 col9" >باعث</td>
#     </tr>

# %%
df = generate_emotion_lexicon(embedding=glf_embedding, emotion="joy", min_cluster_size=13, num_words_to_generate=100)
df
# Out:
# <style type="text/css">
# #T_fc8bb_row0_col1, #T_fc8bb_row0_col2, #T_fc8bb_row0_col3, #T_fc8bb_row0_col4, #T_fc8bb_row0_col5, #T_fc8bb_row0_col6, #T_fc8bb_row1_col6, #T_fc8bb_row2_col2, #T_fc8bb_row2_col3, #T_fc8bb_row3_col3, #T_fc8bb_row3_col5, #T_fc8bb_row11_col6, #T_fc8bb_row15_col2, #T_fc8bb_row15_col3, #T_fc8bb_row16_col5, #T_fc8bb_row17_col2, #T_fc8bb_row18_col3, #T_fc8bb_row22_col6, #T_fc8bb_row23_col2, #T_fc8bb_row23_col5, #T_fc8bb_row27_col6, #T_fc8bb_row32_col6, #T_fc8bb_row35_col0, #T_fc8bb_row35_col6, #T_fc8bb_row39_col1, #T_fc8bb_row39_col5, #T_fc8bb_row42_col1, #T_fc8bb_row43_col2, #T_fc8bb_row46_col6, #T_fc8bb_row48_col3, #T_fc8bb_row56_col2, #T_fc8bb_row58_col1, #T_fc8bb_row65_col0, #T_fc8bb_row71_col1, #T_fc8bb_row88_col6, #T_fc8bb_row93_col6, #T_fc8bb_row96_col6, #T_fc8bb_row97_col5 {
#   background-color: rgba(20, 20, 20, 1);
# }
# </style>
# <table id="T_fc8bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc8bb_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_fc8bb_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_fc8bb_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_fc8bb_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_fc8bb_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_fc8bb_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_fc8bb_level0_col6" class="col_heading level0 col6" >5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc8bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc8bb_row0_col0" class="data row0 col0" >ى</td>
#       <td id="T_fc8bb_row0_col1" class="data row0 col1" >سعادة</td>
#       <td id="T_fc8bb_row0_col2" class="data row0 col2" >سعيد</td>
#       <td id="T_fc8bb_row0_col3" class="data row0 col3" >فرح</td>
#       <td id="T_fc8bb_row0_col4" class="data row0 col4" >مرح</td>
#       <td id="T_fc8bb_row0_col5" class="data row0 col5" >بهجة</td>
#       <td id="T_fc8bb_row0_col6" class="data row0 col6" >مسرور</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc8bb_row1_col0" class="data row1 col0" >لؤي</td>
#       <td id="T_fc8bb_row1_col1" class="data row1 col1" >سعاد</td>
#       <td id="T_fc8bb_row1_col2" class="data row1 col2" >سعيده</td>
#       <td id="T_fc8bb_row1_col3" class="data row1 col3" >فرحة</td>
#       <td id="T_fc8bb_row1_col4" class="data row1 col4" >يمرح</td>
#       <td id="T_fc8bb_row1_col5" class="data row1 col5" >مهجة</td>
#       <td id="T_fc8bb_row1_col6" class="data row1 col6" >سرور</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc8bb_row2_col0" class="data row2 col0" >كلثمي</td>
#       <td id="T_fc8bb_row2_col1" class="data row2 col1" >ياسعادة</td>
#       <td id="T_fc8bb_row2_col2" class="data row2 col2" >عيد</td>
#       <td id="T_fc8bb_row2_col3" class="data row2 col3" >افرح</td>
#       <td id="T_fc8bb_row2_col4" class="data row2 col4" >مرحب</td>
#       <td id="T_fc8bb_row2_col5" class="data row2 col5" >أنعش</td>
#       <td id="T_fc8bb_row2_col6" class="data row2 col6" >مسروق</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc8bb_row3_col0" class="data row3 col0" >كخ</td>
#       <td id="T_fc8bb_row3_col1" class="data row3 col1" >سعاده</td>
#       <td id="T_fc8bb_row3_col2" class="data row3 col2" >أضحى</td>
#       <td id="T_fc8bb_row3_col3" class="data row3 col3" >مفرح</td>
#       <td id="T_fc8bb_row3_col4" class="data row3 col4" >مرحبآ</td>
#       <td id="T_fc8bb_row3_col5" class="data row3 col5" >لهفة</td>
#       <td id="T_fc8bb_row3_col6" class="data row3 col6" >مسعري</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc8bb_row4_col0" class="data row4 col0" >منغص</td>
#       <td id="T_fc8bb_row4_col1" class="data row4 col1" >إسعاد</td>
#       <td id="T_fc8bb_row4_col2" class="data row4 col2" >وعيد</td>
#       <td id="T_fc8bb_row4_col3" class="data row4 col3" >أفرح</td>
#       <td id="T_fc8bb_row4_col4" class="data row4 col4" >سرح</td>
#       <td id="T_fc8bb_row4_col5" class="data row4 col5" >لهف</td>
#       <td id="T_fc8bb_row4_col6" class="data row4 col6" >مسر</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc8bb_row5_col0" class="data row5 col0" >أشمط</td>
#       <td id="T_fc8bb_row5_col1" class="data row5 col1" >سعآد</td>
#       <td id="T_fc8bb_row5_col2" class="data row5 col2" >أسعدتنا</td>
#       <td id="T_fc8bb_row5_col3" class="data row5 col3" >بشوفتك</td>
#       <td id="T_fc8bb_row5_col4" class="data row5 col4" >مرحلة</td>
#       <td id="T_fc8bb_row5_col5" class="data row5 col5" >أيقظ</td>
#       <td id="T_fc8bb_row5_col6" class="data row5 col6" >بخور</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fc8bb_row6_col0" class="data row6 col0" >~</td>
#       <td id="T_fc8bb_row6_col1" class="data row6 col1" >اسعدني</td>
#       <td id="T_fc8bb_row6_col2" class="data row6 col2" >نشكرك</td>
#       <td id="T_fc8bb_row6_col3" class="data row6 col3" >يفرحك</td>
#       <td id="T_fc8bb_row6_col4" class="data row6 col4" >مرؤوس</td>
#       <td id="T_fc8bb_row6_col5" class="data row6 col5" >بهآ</td>
#       <td id="T_fc8bb_row6_col6" class="data row6 col6" >غفور</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fc8bb_row7_col0" class="data row7 col0" >شكسبير</td>
#       <td id="T_fc8bb_row7_col1" class="data row7 col1" >أستودعتك</td>
#       <td id="T_fc8bb_row7_col2" class="data row7 col2" >بمشاركتك</td>
#       <td id="T_fc8bb_row7_col3" class="data row7 col3" >يفرحني</td>
#       <td id="T_fc8bb_row7_col4" class="data row7 col4" >مرحل</td>
#       <td id="T_fc8bb_row7_col5" class="data row7 col5" >يزهر</td>
#       <td id="T_fc8bb_row7_col6" class="data row7 col6" >مسعور</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fc8bb_row8_col0" class="data row8 col0" >أيقظ</td>
#       <td id="T_fc8bb_row8_col1" class="data row8 col1" >أحزن</td>
#       <td id="T_fc8bb_row8_col2" class="data row8 col2" >أعيد</td>
#       <td id="T_fc8bb_row8_col3" class="data row8 col3" >فبشرني</td>
#       <td id="T_fc8bb_row8_col4" class="data row8 col4" >مرقع</td>
#       <td id="T_fc8bb_row8_col5" class="data row8 col5" >ومضة</td>
#       <td id="T_fc8bb_row8_col6" class="data row8 col6" >مسعا</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fc8bb_row9_col0" class="data row9 col0" >هتلر</td>
#       <td id="T_fc8bb_row9_col1" class="data row9 col1" >غادة</td>
#       <td id="T_fc8bb_row9_col2" class="data row9 col2" >سعي</td>
#       <td id="T_fc8bb_row9_col3" class="data row9 col3" >أرح</td>
#       <td id="T_fc8bb_row9_col4" class="data row9 col4" >أشمط</td>
#       <td id="T_fc8bb_row9_col5" class="data row9 col5" >لحى</td>
#       <td id="T_fc8bb_row9_col6" class="data row9 col6" >موفور</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fc8bb_row10_col0" class="data row10 col0" >شآء</td>
#       <td id="T_fc8bb_row10_col1" class="data row10 col1" >ألطف</td>
#       <td id="T_fc8bb_row10_col2" class="data row10 col2" >أستعيد</td>
#       <td id="T_fc8bb_row10_col3" class="data row10 col3" >فرجة</td>
#       <td id="T_fc8bb_row10_col4" class="data row10 col4" >مرحله</td>
#       <td id="T_fc8bb_row10_col5" class="data row10 col5" >رجف</td>
#       <td id="T_fc8bb_row10_col6" class="data row10 col6" >مغفور</td>
#     </tr>
#     <tr>
#       <th id="T_fc8bb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fc8bb_row11_col0" class="data row11 col0" >ذآ</td>
#       <td id="T_fc8bb_row11_col1" class="data row11 col1" >ابتسامة</td>
#       <td id="T_fc8bb_row11_col2" cla

# %% [markdown]
# # Egy

# %%
df = generate_emotion_lexicon(embedding=egy_embedding, emotion="sadness", min_cluster_size=5, num_words_to_generate=100)
df
# Out:
# <style type="text/css">
# #T_16e93_row0_col1, #T_16e93_row0_col2, #T_16e93_row0_col3, #T_16e93_row0_col4, #T_16e93_row0_col5, #T_16e93_row0_col6, #T_16e93_row0_col7, #T_16e93_row0_col8, #T_16e93_row0_col9, #T_16e93_row0_col10, #T_16e93_row0_col11, #T_16e93_row0_col12, #T_16e93_row0_col13, #T_16e93_row0_col14, #T_16e93_row0_col15, #T_16e93_row0_col16, #T_16e93_row0_col17, #T_16e93_row0_col18, #T_16e93_row0_col19, #T_16e93_row1_col10, #T_16e93_row1_col16, #T_16e93_row3_col5, #T_16e93_row4_col13, #T_16e93_row5_col4, #T_16e93_row5_col5, #T_16e93_row6_col2, #T_16e93_row7_col3, #T_16e93_row7_col9, #T_16e93_row7_col13, #T_16e93_row8_col5, #T_16e93_row8_col10, #T_16e93_row8_col14, #T_16e93_row11_col9, #T_16e93_row11_col14, #T_16e93_row12_col4, #T_16e93_row13_col2, #T_16e93_row13_col12, #T_16e93_row16_col5, #T_16e93_row19_col3, #T_16e93_row20_col10, #T_16e93_row21_col4, #T_16e93_row22_col4, #T_16e93_row22_col5, #T_16e93_row22_col16, #T_16e93_row27_col9, #T_16e93_row34_col5, #T_16e93_row34_col17, #T_16e93_row36_col2, #T_16e93_row36_col19, #T_16e93_row38_col7, #T_16e93_row38_col13, #T_16e93_row39_col14, #T_16e93_row40_col2, #T_16e93_row45_col14, #T_16e93_row48_col3, #T_16e93_row48_col9, #T_16e93_row55_col13, #T_16e93_row55_col14, #T_16e93_row62_col4, #T_16e93_row62_col12, #T_16e93_row68_col0, #T_16e93_row69_col3, #T_16e93_row70_col7, #T_16e93_row72_col7, #T_16e93_row77_col16, #T_16e93_row83_col14, #T_16e93_row89_col17, #T_16e93_row92_col14, #T_16e93_row94_col15, #T_16e93_row95_col6, #T_16e93_row98_col7, #T_16e93_row98_col15 {
#   background-color: rgba(20, 20, 20, 1);
# }
# </style>
# <table id="T_16e93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16e93_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_16e93_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_16e93_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_16e93_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_16e93_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_16e93_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_16e93_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_16e93_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_16e93_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_16e93_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_16e93_level0_col10" class="col_heading level0 col10" >9</th>
#       <th id="T_16e93_level0_col11" class="col_heading level0 col11" >10</th>
#       <th id="T_16e93_level0_col12" class="col_heading level0 col12" >11</th>
#       <th id="T_16e93_level0_col13" class="col_heading level0 col13" >12</th>
#       <th id="T_16e93_level0_col14" class="col_heading level0 col14" >13</th>
#       <th id="T_16e93_level0_col15" class="col_heading level0 col15" >14</th>
#       <th id="T_16e93_level0_col16" class="col_heading level0 col16" >15</th>
#       <th id="T_16e93_level0_col17" class="col_heading level0 col17" >16</th>
#       <th id="T_16e93_level0_col18" class="col_heading level0 col18" >17</th>
#       <th id="T_16e93_level0_col19" class="col_heading level0 col19" >18</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16e93_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16e93_row0_col0" class="data row0 col0" >بآ</td>
#       <td id="T_16e93_row0_col1" class="data row0 col1" >ندم</td>
#       <td id="T_16e93_row0_col2" class="data row0 col2" >اسف</td>
#       <td id="T_16e93_row0_col3" class="data row0 col3" >حزين</td>
#       <td id="T_16e93_row0_col4" class="data row0 col4" >حزن</td>
#       <td id="T_16e93_row0_col5" class="data row0 col5" >أسف</td>
#       <td id="T_16e93_row0_col6" class="data row0 col6" >غم</td>
#       <td id="T_16e93_row0_col7" class="data row0 col7" >بؤس</td>
#       <td id="T_16e93_row0_col8" class="data row0 col8" >نادم</td>
#       <td id="T_16e93_row0_col9" class="data row0 col9" >بائس</td>
#       <td id="T_16e93_row0_col10" class="data row0 col10" >آسف</td>
#       <td id="T_16e93_row0_col11" class="data row0 col11" >أسى</td>
#       <td id="T_16e93_row0_col12" class="data row0 col12" >كئيب</td>
#       <td id="T_16e93_row0_col13" class="data row0 col13" >محزن</td>
#       <td id="T_16e93_row0_col14" class="data row0 col14" >محبط</td>
#       <td id="T_16e93_row0_col15" class="data row0 col15" >كدر</td>
#       <td id="T_16e93_row0_col16" class="data row0 col16" >تعيس</td>
#       <td id="T_16e93_row0_col17" class="data row0 col17" >متشائم</td>
#       <td id="T_16e93_row0_col18" class="data row0 col18" >انقباض</td>
#       <td id="T_16e93_row0_col19" class="data row0 col19" >مفجوع</td>
#     </tr>
#     <tr>
#       <th id="T_16e93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16e93_row1_col0" class="data row1 col0" >ئ</td>
#       <td id="T_16e93_row1_col1" class="data row1 col1" >أفندم</td>
#       <td id="T_16e93_row1_col2" class="data row1 col2" >ااسف</td>
#       <td id="T_16e93_row1_col3" class="data row1 col3" >حز</td>
#       <td id="T_16e93_row1_col4" class="data row1 col4" >احزن</td>
#       <td id="T_16e93_row1_col5" class="data row1 col5" >اتأسف</td>
#       <td id="T_16e93_row1_col6" class="data row1 col6" >تغم</td>
#       <td id="T_16e93_row1_col7" class="data row1 col7" >بؤقك</td>
#       <td id="T_16e93_row1_col8" class="data row1 col8" >نادا</td>
#       <td id="T_16e93_row1_col9" class="data row1 col9" >متفائل</td>
#       <td id="T_16e93_row1_col10" class="data row1 col10" >متأسف</td>
#       <td id="T_16e93_row1_col11" class="data row1 col11" >أسطى</td>
#       <td id="T_16e93_row1_col12" class="data row1 col12" >كئيبه</td>
#       <td id="T_16e93_row1_col13" class="data row1 col13" >احزن</td>
#       <td id="T_16e93_row1_col14" class="data row1 col14" >محبب</td>
#       <td id="T_16e93_row1_col15" class="data row1 col15" >حدر</td>
#       <td id="T_16e93_row1_col16" class="data row1 col16" >تعس</td>
#       <td id="T_16e93_row1_col17" class="data row1 col17" >تشائم</td>
#       <td id="T_16e93_row1_col18" class="data row1 col18" >انقر</td>
#       <td id="T_16e93_row1_col19" class="data row1 col19" >مجوع</td>
#     </tr>
#     <tr>
#       <th id="T_16e93_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16e93_row2_col0" class="data row2 col0" >رثا</td>
#       <td id="T_16e93_row2_col1" class="data row2 col1" >افندم</td>
#       <td id="T_16e93_row2_col2" class="data row2 col2" >نتاسف</td>
#       <td id="T_16e93_row2_col3" class="data row2 col3" >رزين</td>
#       <td id="T_16e93_row2_col4" class="data row2 col4" >نحزن</td>
#       <td id="T_16e93_row2_col5" class="data row2 col5" >نتأسف</td>
#       <td id="T_16e93_row2_col6" class="data row2 col6" >غمز</td>
#       <td id="T_16e93_row2_col7" class="data row2 col7" >بؤ</td>
#       <td id="T_16e93_row2_col8" class="data row2 col8" >بنادمين</td>
#       <td id="T_16e93_row2_col9" class="data row2 col9" >باهت</td>
#       <td id="T_16e93_row2_col10" class="data row2 col10" >اتأسف</td>
#       <td id="T_16e93_row2_col11" class="data row2 col11" >أس</td>
#       <td id="T_16e93_row2_col12" class="data row2 col12" >حبعمرى</td>
#       <td id="T_16e93_row2_col13" class="data row2 col13" >نحزن</td>
#       <td id="T_16e93_row2_col14" class="data row2 col14" >محبت</td>
#       <td id="T_16e93_row2_col15" class="data row2 col15" >ئادر</td>
#       <td id="T_16e93_row2_col16" class="data row2 col16" >تعك</td>
#       <td id="T_16e93_row2_col17" class="data row2 col17" >متشالة</td>
#       <td id="T_16e93_row2_col18" class="data row2 col18" >انقد</td>
#       <td id="T_16e93_row2_col19" class="data row2 col19" >هجوع</td>
#     </tr>
#     <tr>
#       <th id="T_16e93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16e93_row3_col0" class="data row3 col0" >لؤلؤ</td>
#       <td id="T_16e93_row3_col1" class="data row3 col1" >اندم</td>
#       <td id="T_16e93_row3_col2" class="data row3 col2" >تاسف</td>
#       <td id="T_16e93_row3_col3" class="data row3 col3" >حزنى</td>
#       <td id="T_16e93_row3_col4" class="data row3 col4

# %%
df = generate_emotion_lexicon(embedding=egy_embedding, emotion="anger", min_cluster_size=9, num_words_to_generate=100)
df
# Out:
# <style type="text/css">
# #T_5f3f0_row0_col1, #T_5f3f0_row0_col2, #T_5f3f0_row0_col3, #T_5f3f0_row0_col4, #T_5f3f0_row0_col5, #T_5f3f0_row0_col6, #T_5f3f0_row0_col7, #T_5f3f0_row0_col8, #T_5f3f0_row0_col9, #T_5f3f0_row0_col10, #T_5f3f0_row1_col9, #T_5f3f0_row2_col5, #T_5f3f0_row2_col6, #T_5f3f0_row3_col2, #T_5f3f0_row3_col4, #T_5f3f0_row3_col5, #T_5f3f0_row3_col6, #T_5f3f0_row5_col3, #T_5f3f0_row5_col6, #T_5f3f0_row5_col9, #T_5f3f0_row6_col2, #T_5f3f0_row6_col3, #T_5f3f0_row7_col5, #T_5f3f0_row7_col10, #T_5f3f0_row11_col2, #T_5f3f0_row11_col6, #T_5f3f0_row11_col7, #T_5f3f0_row17_col8, #T_5f3f0_row18_col2, #T_5f3f0_row19_col4, #T_5f3f0_row20_col2, #T_5f3f0_row21_col2, #T_5f3f0_row25_col6, #T_5f3f0_row29_col1, #T_5f3f0_row32_col2, #T_5f3f0_row33_col8, #T_5f3f0_row34_col1, #T_5f3f0_row35_col8, #T_5f3f0_row37_col2, #T_5f3f0_row38_col4, #T_5f3f0_row48_col3, #T_5f3f0_row50_col9, #T_5f3f0_row62_col5, #T_5f3f0_row63_col5, #T_5f3f0_row67_col2, #T_5f3f0_row68_col1, #T_5f3f0_row71_col9, #T_5f3f0_row77_col1, #T_5f3f0_row78_col10, #T_5f3f0_row79_col7, #T_5f3f0_row82_col6, #T_5f3f0_row85_col8, #T_5f3f0_row86_col9, #T_5f3f0_row86_col10, #T_5f3f0_row88_col7, #T_5f3f0_row97_col1 {
#   background-color: rgba(20, 20, 20, 1);
# }
# </style>
# <table id="T_5f3f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f3f0_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_5f3f0_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_5f3f0_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_5f3f0_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_5f3f0_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_5f3f0_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_5f3f0_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_5f3f0_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_5f3f0_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_5f3f0_level0_col9" class="col_heading level0 col9" >8</th>
#       <th id="T_5f3f0_level0_col10" class="col_heading level0 col10" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f3f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f3f0_row0_col0" class="data row0 col0" >بآ</td>
#       <td id="T_5f3f0_row0_col1" class="data row0 col1" >كره</td>
#       <td id="T_5f3f0_row0_col2" class="data row0 col2" >حقد</td>
#       <td id="T_5f3f0_row0_col3" class="data row0 col3" >حسد</td>
#       <td id="T_5f3f0_row0_col4" class="data row0 col4" >طمع</td>
#       <td id="T_5f3f0_row0_col5" class="data row0 col5" >حاقد</td>
#       <td id="T_5f3f0_row0_col6" class="data row0 col6" >غضب</td>
#       <td id="T_5f3f0_row0_col7" class="data row0 col7" >عداء</td>
#       <td id="T_5f3f0_row0_col8" class="data row0 col8" >كراهية</td>
#       <td id="T_5f3f0_row0_col9" class="data row0 col9" >بغض</td>
#       <td id="T_5f3f0_row0_col10" class="data row0 col10" >غاضب</td>
#     </tr>
#     <tr>
#       <th id="T_5f3f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f3f0_row1_col0" class="data row1 col0" >ئ</td>
#       <td id="T_5f3f0_row1_col1" class="data row1 col1" >عكره</td>
#       <td id="T_5f3f0_row1_col2" class="data row1 col2" >نحقد</td>
#       <td id="T_5f3f0_row1_col3" class="data row1 col3" >نحسد</td>
#       <td id="T_5f3f0_row1_col4" class="data row1 col4" >طمعان</td>
#       <td id="T_5f3f0_row1_col5" class="data row1 col5" >حاقضين</td>
#       <td id="T_5f3f0_row1_col6" class="data row1 col6" >غضبة</td>
#       <td id="T_5f3f0_row1_col7" class="data row1 col7" >أعداء</td>
#       <td id="T_5f3f0_row1_col8" class="data row1 col8" >كراهي</td>
#       <td id="T_5f3f0_row1_col9" class="data row1 col9" >بغيض</td>
#       <td id="T_5f3f0_row1_col10" class="data row1 col10" >غاض</td>
#     </tr>
#     <tr>
#       <th id="T_5f3f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5f3f0_row2_col0" class="data row2 col0" >بزيئ</td>
#       <td id="T_5f3f0_row2_col1" class="data row2 col1" >أكره</td>
#       <td id="T_5f3f0_row2_col2" class="data row2 col2" >تحقد</td>
#       <td id="T_5f3f0_row2_col3" class="data row2 col3" >احسد</td>
#       <td id="T_5f3f0_row2_col4" class="data row2 col4" >مطمع</td>
#       <td id="T_5f3f0_row2_col5" class="data row2 col5" >أنف</td>
#       <td id="T_5f3f0_row2_col6" class="data row2 col6" >أغضب</td>
#       <td id="T_5f3f0_row2_col7" class="data row2 col7" >اعداء</td>
#       <td id="T_5f3f0_row2_col8" class="data row2 col8" >كراهيه</td>
#       <td id="T_5f3f0_row2_col9" class="data row2 col9" >بغ</td>
#       <td id="T_5f3f0_row2_col10" class="data row2 col10" >غا</td>
#     </tr>
#     <tr>
#       <th id="T_5f3f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5f3f0_row3_col0" class="data row3 col0" >ثح</td>
#       <td id="T_5f3f0_row3_col1" class="data row3 col1" >اكره</td>
#       <td id="T_5f3f0_row3_col2" class="data row3 col2" >حاقد</td>
#       <td id="T_5f3f0_row3_col3" class="data row3 col3" >تتحسد</td>
#       <td id="T_5f3f0_row3_col4" class="data row3 col4" >جشع</td>
#       <td id="T_5f3f0_row3_col5" class="data row3 col5" >حاسد</td>
#       <td id="T_5f3f0_row3_col6" class="data row3 col6" >غضبان</td>
#       <td id="T_5f3f0_row3_col7" class="data row3 col7" >يااعداء</td>
#       <td id="T_5f3f0_row3_col8" class="data row3 col8" >ناهية</td>
#       <td id="T_5f3f0_row3_col9" class="data row3 col9" >نغض</td>
#       <td id="T_5f3f0_row3_col10" class="data row3 col10" >غامض</td>
#     </tr>
#     <tr>
#       <th id="T_5f3f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5f3f0_row4_col0" class="data row4 col0" >آ</td>
#       <td id="T_5f3f0_row4_col1" class="data row4 col1" >تزكره</td>
#       <td id="T_5f3f0_row4_col2" class="data row4 col2" >حقكك</td>
#       <td id="T_5f3f0_row4_col3" class="data row4 col3" >حسل</td>
#       <td id="T_5f3f0_row4_col4" class="data row4 col4" >يبأ</td>
#       <td id="T_5f3f0_row4_col5" class="data row4 col5" >انف</td>
#       <td id="T_5f3f0_row4_col6" class="data row4 col6" >عضب</td>
#       <td id="T_5f3f0_row4_col7" class="data row4 col7" >فداء</td>
#       <td id="T_5f3f0_row4_col8" class="data row4 col8" >إكراه</td>
#       <td id="T_5f3f0_row4_col9" class="data row4 col9" >يقاتلونكم</td>
#       <td id="T_5f3f0_row4_col10" class="data row4 col10" >غاضني</td>
#     </tr>
#     <tr>
#       <th id="T_5f3f0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5f3f0_row5_col0" class="data row5 col0" >ᴉ</td>
#       <td id="T_5f3f0_row5_col1" class="data row5 col1" >عفكره</td>
#       <td id="T_5f3f0_row5_col2" class="data row5 col2" >حاقضين</td>
#       <td id="T_5f3f0_row5_col3" class="data row5 col3" >حسود</td>
#       <td id="T_5f3f0_row5_col4" class="data row5 col4" >يريكم</td>
#       <td id="T_5f3f0_row5_col5" class="data row5 col5" >حاق</td>
#       <td id="T_5f3f0_row5_col6" class="data row5 col6" >مقت</td>
#       <td id="T_5f3f0_row5_col7" class="data row5 col7" >اخاء</td>
#       <td id="T_5f3f0_row5_col8" class="data row5 col8" >ماهية</td>
#       <td id="T_5f3f0_row5_col9" class="data row5 col9" >بغي</td>
#       <td id="T_5f3f0_row5_col10" class="data row5 col10" >لاتغضب</td>
#     </tr>
#     <tr>
#       <th id="T_5f3f0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5f3f0_row6_col0" class="data row6 col0" >لؤلؤ</td>
#       <td id="T_5f3f0_row6_col1" class="data row6 col1" >هكرهك</td>
#       <td id="T_5f3f0_row6_col2" class="data row6 col2" >كراهية</td>
#       <td id="T_5f3f0_row6_col3" class="data row6 col3" >حاسد</td>
#       <td id="T_5f3f0_row6_col4" class="data row6 col4" >ابجار</td>
#       <td id="T_5f3f0_row6_col5" class="data row6 col5" >اثرالعراق</td>
#       <td id="T_5f3f0_row6_col6" class="data row6 col6" >قضب</td>
#       <td id="T_5f3f0_row6_col7" class="data row6 col7" >غداء</td>
#       <td id="T_5f3f0_row6_col8" class="data row6 col8" >تثنية</td>
#       <td id="T_5f3f0_row6_col9" class="data row6 col9" >بغا</td>
#       <td id="T_5f3f0_row6_col10" class="data row6 col10" >يؤخذ</td

# %% [markdown]
# # Lev

# %%
df = generate_emotion_lexicon(embedding=lev_embedding, emotion="disgust", min_cluster_size=5, num_words_to_generate=100)
df
# Out:
# <style type="text/css">
# #T_c2e56_row0_col1, #T_c2e56_row0_col2, #T_c2e56_row0_col3, #T_c2e56_row0_col4, #T_c2e56_row0_col5, #T_c2e56_row0_col6, #T_c2e56_row2_col6, #T_c2e56_row8_col2, #T_c2e56_row12_col2, #T_c2e56_row53_col0, #T_c2e56_row56_col6, #T_c2e56_row76_col0, #T_c2e56_row83_col4, #T_c2e56_row88_col0, #T_c2e56_row95_col0 {
#   background-color: rgba(20, 20, 20, 1);
# }
# </style>
# <table id="T_c2e56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2e56_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_c2e56_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_c2e56_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_c2e56_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_c2e56_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_c2e56_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_c2e56_level0_col6" class="col_heading level0 col6" >5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2e56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2e56_row0_col0" class="data row0 col0" >ى</td>
#       <td id="T_c2e56_row0_col1" class="data row0 col1" >كريه</td>
#       <td id="T_c2e56_row0_col2" class="data row0 col2" >قرف</td>
#       <td id="T_c2e56_row0_col3" class="data row0 col3" >سقم</td>
#       <td id="T_c2e56_row0_col4" class="data row0 col4" >مقيت</td>
#       <td id="T_c2e56_row0_col5" class="data row0 col5" >سئم</td>
#       <td id="T_c2e56_row0_col6" class="data row0 col6" >بغيض</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c2e56_row1_col0" class="data row1 col0" >ىا</td>
#       <td id="T_c2e56_row1_col1" class="data row1 col1" >فكريه</td>
#       <td id="T_c2e56_row1_col2" class="data row1 col2" >يقرف</td>
#       <td id="T_c2e56_row1_col3" class="data row1 col3" >يعافينا</td>
#       <td id="T_c2e56_row1_col4" class="data row1 col4" >تفتيت</td>
#       <td id="T_c2e56_row1_col5" class="data row1 col5" >لائم</td>
#       <td id="T_c2e56_row1_col6" class="data row1 col6" >بغي</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c2e56_row2_col0" class="data row2 col0" >نلطم</td>
#       <td id="T_c2e56_row2_col1" class="data row2 col1" >آيه</td>
#       <td id="T_c2e56_row2_col2" class="data row2 col2" >اقرف</td>
#       <td id="T_c2e56_row2_col3" class="data row2 col3" >أشفي</td>
#       <td id="T_c2e56_row2_col4" class="data row2 col4" >مقيط</td>
#       <td id="T_c2e56_row2_col5" class="data row2 col5" >ائم</td>
#       <td id="T_c2e56_row2_col6" class="data row2 col6" >بغض</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c2e56_row3_col0" class="data row3 col0" >سذج</td>
#       <td id="T_c2e56_row3_col1" class="data row3 col1" >بريه</td>
#       <td id="T_c2e56_row3_col2" class="data row3 col2" >يقرفكم</td>
#       <td id="T_c2e56_row3_col3" class="data row3 col3" >اشفي</td>
#       <td id="T_c2e56_row3_col4" class="data row3 col4" >تثبيت</td>
#       <td id="T_c2e56_row3_col5" class="data row3 col5" >شؤم</td>
#       <td id="T_c2e56_row3_col6" class="data row3 col6" >بغا</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c2e56_row4_col0" class="data row4 col0" >لئن</td>
#       <td id="T_c2e56_row4_col1" class="data row4 col1" >سخريه</td>
#       <td id="T_c2e56_row4_col2" class="data row4 col2" >تقرف</td>
#       <td id="T_c2e56_row4_col3" class="data row4 col3" >ويغفرله</td>
#       <td id="T_c2e56_row4_col4" class="data row4 col4" >مقتبس</td>
#       <td id="T_c2e56_row4_col5" class="data row4 col5" >؛</td>
#       <td id="T_c2e56_row4_col6" class="data row4 col6" >بغية</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c2e56_row5_col0" class="data row5 col0" >’</td>
#       <td id="T_c2e56_row5_col1" class="data row5 col1" >قريه</td>
#       <td id="T_c2e56_row5_col2" class="data row5 col2" >قرفتونا</td>
#       <td id="T_c2e56_row5_col3" class="data row5 col3" >اامين</td>
#       <td id="T_c2e56_row5_col4" class="data row5 col4" >بذخ</td>
#       <td id="T_c2e56_row5_col5" class="data row5 col5" >سذج</td>
#       <td id="T_c2e56_row5_col6" class="data row5 col6" >آبتسم</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c2e56_row6_col0" class="data row6 col0" >سئ</td>
#       <td id="T_c2e56_row6_col1" class="data row6 col1" >شوفريه</td>
#       <td id="T_c2e56_row6_col2" class="data row6 col2" >قرفناكم</td>
#       <td id="T_c2e56_row6_col3" class="data row6 col3" >آمييين</td>
#       <td id="T_c2e56_row6_col4" class="data row6 col4" >سئ</td>
#       <td id="T_c2e56_row6_col5" class="data row6 col5" >يتلائم</td>
#       <td id="T_c2e56_row6_col6" class="data row6 col6" >سذج</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c2e56_row7_col0" class="data row7 col0" >يسخطك</td>
#       <td id="T_c2e56_row7_col1" class="data row7 col1" >حريه</td>
#       <td id="T_c2e56_row7_col2" class="data row7 col2" >قرفتنا</td>
#       <td id="T_c2e56_row7_col3" class="data row7 col3" >يشافيه</td>
#       <td id="T_c2e56_row7_col4" class="data row7 col4" >مغناطيسي</td>
#       <td id="T_c2e56_row7_col5" class="data row7 col5" >وغد</td>
#       <td id="T_c2e56_row7_col6" class="data row7 col6" >غيض</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c2e56_row8_col0" class="data row8 col0" >طغاه</td>
#       <td id="T_c2e56_row8_col1" class="data row8 col1" >قطريه</td>
#       <td id="T_c2e56_row8_col2" class="data row8 col2" >مقرف</td>
#       <td id="T_c2e56_row8_col3" class="data row8 col3" >يشافيك</td>
#       <td id="T_c2e56_row8_col4" class="data row8 col4" >نهضة</td>
#       <td id="T_c2e56_row8_col5" class="data row8 col5" >تشرذم</td>
#       <td id="T_c2e56_row8_col6" class="data row8 col6" >خسئتم</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c2e56_row9_col0" class="data row9 col0" >اوساخ</td>
#       <td id="T_c2e56_row9_col1" class="data row9 col1" >روايه</td>
#       <td id="T_c2e56_row9_col2" class="data row9 col2" >يقرفك</td>
#       <td id="T_c2e56_row9_col3" class="data row9 col3" >ويصبراهلهم</td>
#       <td id="T_c2e56_row9_col4" class="data row9 col4" >مهاترات</td>
#       <td id="T_c2e56_row9_col5" class="data row9 col5" >ملائم</td>
#       <td id="T_c2e56_row9_col6" class="data row9 col6" >أنذر</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c2e56_row10_col0" class="data row10 col0" >خبائث</td>
#       <td id="T_c2e56_row10_col1" class="data row10 col1" >عبريه</td>
#       <td id="T_c2e56_row10_col2" class="data row10 col2" >قرفونا</td>
#       <td id="T_c2e56_row10_col3" class="data row10 col3" >وثب</td>
#       <td id="T_c2e56_row10_col4" class="data row10 col4" >تشتيت</td>
#       <td id="T_c2e56_row10_col5" class="data row10 col5" >بذخ</td>
#       <td id="T_c2e56_row10_col6" class="data row10 col6" >طغو</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c2e56_row11_col0" class="data row11 col0" >ضفادع</td>
#       <td id="T_c2e56_row11_col1" class="data row11 col1" >ذريه</td>
#       <td id="T_c2e56_row11_col2" class="data row11 col2" >ئرف</td>
#       <td id="T_c2e56_row11_col3" class="data row11 col3" >ياارحم</td>
#       <td id="T_c2e56_row11_col4" class="data row11 col4" >تجنب</td>
#       <td id="T_c2e56_row11_col5" class="data row11 col5" >تجزئة</td>
#       <td id="T_c2e56_row11_col6" class="data row11 col6" >أخنس</td>
#     </tr>
#     <tr>
#       <th id="T_c2e56_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c2e56_row12_col0" class="data row12 col0" >جحاش</td>

# %% [markdown]
# # IRQ

# %%
df = generate_emotion_lexicon(embedding=irq_embedding, emotion="sadness", min_cluster_size=9, num_words_to_generate=100)
df
# Out:
# <style type="text/css">
# #T_00395_row0_col1, #T_00395_row0_col2, #T_00395_row0_col3, #T_00395_row0_col4, #T_00395_row0_col5, #T_00395_row0_col6, #T_00395_row0_col7, #T_00395_row0_col8, #T_00395_row0_col9, #T_00395_row1_col3, #T_00395_row2_col2, #T_00395_row2_col5, #T_00395_row2_col9, #T_00395_row6_col3, #T_00395_row8_col1, #T_00395_row8_col2, #T_00395_row9_col5, #T_00395_row10_col6, #T_00395_row17_col1, #T_00395_row19_col0, #T_00395_row43_col2, #T_00395_row44_col2, #T_00395_row52_col0, #T_00395_row61_col3, #T_00395_row62_col4, #T_00395_row64_col4, #T_00395_row65_col8, #T_00395_row66_col2, #T_00395_row73_col5, #T_00395_row86_col9, #T_00395_row90_col0, #T_00395_row91_col4 {
#   background-color: rgba(20, 20, 20, 1);
# }
# </style>
# <table id="T_00395">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00395_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_00395_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_00395_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_00395_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_00395_level0_col4" class="col_heading level0 col4" >3</th>
#       <th id="T_00395_level0_col5" class="col_heading level0 col5" >4</th>
#       <th id="T_00395_level0_col6" class="col_heading level0 col6" >5</th>
#       <th id="T_00395_level0_col7" class="col_heading level0 col7" >6</th>
#       <th id="T_00395_level0_col8" class="col_heading level0 col8" >7</th>
#       <th id="T_00395_level0_col9" class="col_heading level0 col9" >8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00395_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00395_row0_col0" class="data row0 col0" >Ꭿ</td>
#       <td id="T_00395_row0_col1" class="data row0 col1" >ندم</td>
#       <td id="T_00395_row0_col2" class="data row0 col2" >حزين</td>
#       <td id="T_00395_row0_col3" class="data row0 col3" >حزن</td>
#       <td id="T_00395_row0_col4" class="data row0 col4" >نادم</td>
#       <td id="T_00395_row0_col5" class="data row0 col5" >محزن</td>
#       <td id="T_00395_row0_col6" class="data row0 col6" >بائس</td>
#       <td id="T_00395_row0_col7" class="data row0 col7" >بؤس</td>
#       <td id="T_00395_row0_col8" class="data row0 col8" >مفجوع</td>
#       <td id="T_00395_row0_col9" class="data row0 col9" >كئيب</td>
#     </tr>
#     <tr>
#       <th id="T_00395_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00395_row1_col0" class="data row1 col0" >ى</td>
#       <td id="T_00395_row1_col1" class="data row1 col1" >شيءندم</td>
#       <td id="T_00395_row1_col2" class="data row1 col2" >كتوم</td>
#       <td id="T_00395_row1_col3" class="data row1 col3" >محزن</td>
#       <td id="T_00395_row1_col4" class="data row1 col4" >نادية</td>
#       <td id="T_00395_row1_col5" class="data row1 col5" >أحزن</td>
#       <td id="T_00395_row1_col6" class="data row1 col6" >بائع</td>
#       <td id="T_00395_row1_col7" class="data row1 col7" >مأزق</td>
#       <td id="T_00395_row1_col8" class="data row1 col8" >خشوع</td>
#       <td id="T_00395_row1_col9" class="data row1 col9" >نحيب</td>
#     </tr>
#     <tr>
#       <th id="T_00395_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00395_row2_col0" class="data row2 col0" >يؤم</td>
#       <td id="T_00395_row2_col1" class="data row2 col1" >اندم</td>
#       <td id="T_00395_row2_col2" class="data row2 col2" >كآبة</td>
#       <td id="T_00395_row2_col3" class="data row2 col3" >آلحزن</td>
#       <td id="T_00395_row2_col4" class="data row2 col4" >بإس</td>
#       <td id="T_00395_row2_col5" class="data row2 col5" >حزن</td>
#       <td id="T_00395_row2_col6" class="data row2 col6" >ذريع</td>
#       <td id="T_00395_row2_col7" class="data row2 col7" >ذراع</td>
#       <td id="T_00395_row2_col8" class="data row2 col8" >ى</td>
#       <td id="T_00395_row2_col9" class="data row2 col9" >تأنيب</td>
#     </tr>
#     <tr>
#       <th id="T_00395_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00395_row3_col0" class="data row3 col0" >غمز</td>
#       <td id="T_00395_row3_col1" class="data row3 col1" >عليهأجاب</td>
#       <td id="T_00395_row3_col2" class="data row3 col2" >تخزين</td>
#       <td id="T_00395_row3_col3" class="data row3 col3" >احزن</td>
#       <td id="T_00395_row3_col4" class="data row3 col4" >آدم</td>
#       <td id="T_00395_row3_col5" class="data row3 col5" >احزن</td>
#       <td id="T_00395_row3_col6" class="data row3 col6" >بائد</td>
#       <td id="T_00395_row3_col7" class="data row3 col7" >طغو</td>
#       <td id="T_00395_row3_col8" class="data row3 col8" >مزدحم</td>
#       <td id="T_00395_row3_col9" class="data row3 col9" >عصيب</td>
#     </tr>
#     <tr>
#       <th id="T_00395_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00395_row4_col0" class="data row4 col0" >ذ</td>
#       <td id="T_00395_row4_col1" class="data row4 col1" >ثمانون</td>
#       <td id="T_00395_row4_col2" class="data row4 col2" >خلوني</td>
#       <td id="T_00395_row4_col3" class="data row4 col3" >أحزن</td>
#       <td id="T_00395_row4_col4" class="data row4 col4" >ادم</td>
#       <td id="T_00395_row4_col5" class="data row4 col5" >آلحزن</td>
#       <td id="T_00395_row4_col6" class="data row4 col6" >طغا</td>
#       <td id="T_00395_row4_col7" class="data row4 col7" >يدعونك</td>
#       <td id="T_00395_row4_col8" class="data row4 col8" >مفخخه</td>
#       <td id="T_00395_row4_col9" class="data row4 col9" >تطيب</td>
#     </tr>
#     <tr>
#       <th id="T_00395_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_00395_row5_col0" class="data row5 col0" >آ</td>
#       <td id="T_00395_row5_col1" class="data row5 col1" >أتبرع</td>
#       <td id="T_00395_row5_col2" class="data row5 col2" >دايم</td>
#       <td id="T_00395_row5_col3" class="data row5 col3" >حز</td>
#       <td id="T_00395_row5_col4" class="data row5 col4" >اغفو</td>
#       <td id="T_00395_row5_col5" class="data row5 col5" >مآآبكي</td>
#       <td id="T_00395_row5_col6" class="data row5 col6" >إجحاف</td>
#       <td id="T_00395_row5_col7" class="data row5 col7" >خنق</td>
#       <td id="T_00395_row5_col8" class="data row5 col8" >جوع</td>
#       <td id="T_00395_row5_col9" class="data row5 col9" >مغيب</td>
#     </tr>
#     <tr>
#       <th id="T_00395_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_00395_row6_col0" class="data row6 col0" >هففف</td>
#       <td id="T_00395_row6_col1" class="data row6 col1" >روائي</td>
#       <td id="T_00395_row6_col2" class="data row6 col2" >انحب</td>
#       <td id="T_00395_row6_col3" class="data row6 col3" >خزن</td>
#       <td id="T_00395_row6_col4" class="data row6 col4" >غفا</td>
#       <td id="T_00395_row6_col5" class="data row6 col5" >لاتحزن</td>
#       <td id="T_00395_row6_col6" class="data row6 col6" >تثقيف</td>
#       <td id="T_00395_row6_col7" class="data row6 col7" >بوركتم</td>
#       <td id="T_00395_row6_col8" class="data row6 col8" >هففف</td>
#       <td id="T_00395_row6_col9" class="data row6 col9" >لاأعرفك</td>
#     </tr>
#     <tr>
#       <th id="T_00395_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_00395_row7_col0" class="data row7 col0" >أقتنعت</td>
#       <td id="T_00395_row7_col1" class="data row7 col1" >ندمان</td>
#       <td id="T_00395_row7_col2" class="data row7 col2" >متوحد</td>
#       <td id="T_00395_row7_col3" class="data row7 col3" >سومرست</td>
#       <td id="T_00395_row7_col4" class="data row7 col4" >نادى</td>
#       <td id="T_00395_row7_col5" class="data row7 col5" >محا</td>
#       <td id="T_00395_row7_col6" class="data row7 col6" >حذو</td>
#       <td id="T_00395_row7_col7" class="data row7 col7" >آ</td>
#       <td id="T_00395_row7_col8" class="data row7 col8" >مفضله</td>
#       <td id="T_00395_row7_col9" class="data row7 col9" >تسيب</td>
#     </tr>
#     <tr>
#       <th id="T_00395_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_00395_row8_col0" class="data row8 col0" >اصدقائك</td>
#       <td id="T_00395_row8_col1" class="data row8 col1" >تعيس</td>
#       <td id="T_00395_row8_col2" class="data row8 col2" >منهك</td>

# %%
df = generate_emotion_lexicon(embedding=irq_embedding, emotion="surprise", min_cluster_size=5, num_words_to_generate=100)
df
# Out:
# <style type="text/css">
# #T_8d26d_row0_col1, #T_8d26d_row0_col2, #T_8d26d_row0_col3, #T_8d26d_row0_col4, #T_8d26d_row1_col2, #T_8d26d_row1_col3, #T_8d26d_row2_col1, #T_8d26d_row5_col1, #T_8d26d_row5_col4, #T_8d26d_row10_col1, #T_8d26d_row10_col3, #T_8d26d_row12_col1, #T_8d26d_row22_col1, #T_8d26d_row31_col2, #T_8d26d_row45_col1, #T_8d26d_row46_col1, #T_8d26d_row47_col4, #T_8d26d_row54_col4 {
#   background-color: rgba(20, 20, 20, 1);
# }
# </style>
# <table id="T_8d26d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d26d_level0_col0" class="col_heading level0 col0" >-1</th>
#       <th id="T_8d26d_level0_col1" class="col_heading level0 col1" >0</th>
#       <th id="T_8d26d_level0_col2" class="col_heading level0 col2" >1</th>
#       <th id="T_8d26d_level0_col3" class="col_heading level0 col3" >2</th>
#       <th id="T_8d26d_level0_col4" class="col_heading level0 col4" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d26d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d26d_row0_col0" class="data row0 col0" >هففف</td>
#       <td id="T_8d26d_row0_col1" class="data row0 col1" >عجب</td>
#       <td id="T_8d26d_row0_col2" class="data row0 col2" >مفاجئ</td>
#       <td id="T_8d26d_row0_col3" class="data row0 col3" >مذهل</td>
#       <td id="T_8d26d_row0_col4" class="data row0 col4" >ذهل</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d26d_row1_col0" class="data row1 col0" >Ꭿ</td>
#       <td id="T_8d26d_row1_col1" class="data row1 col1" >اعجب</td>
#       <td id="T_8d26d_row1_col2" class="data row1 col2" >دهشة</td>
#       <td id="T_8d26d_row1_col3" class="data row1 col3" >ذهل</td>
#       <td id="T_8d26d_row1_col4" class="data row1 col4" >ذهآبك</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d26d_row2_col0" class="data row2 col0" >بصفحتك</td>
#       <td id="T_8d26d_row2_col1" class="data row2 col1" >تعجب</td>
#       <td id="T_8d26d_row2_col2" class="data row2 col2" >Ꭿ</td>
#       <td id="T_8d26d_row2_col3" class="data row2 col3" >أفعآله</td>
#       <td id="T_8d26d_row2_col4" class="data row2 col4" >أذهل</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d26d_row3_col0" class="data row3 col0" >يؤم</td>
#       <td id="T_8d26d_row3_col1" class="data row3 col1" >تنعجب</td>
#       <td id="T_8d26d_row3_col2" class="data row3 col2" >آ</td>
#       <td id="T_8d26d_row3_col3" class="data row3 col3" >ردآ</td>
#       <td id="T_8d26d_row3_col4" class="data row3 col4" >ركآم</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d26d_row4_col0" class="data row4 col0" >ضفادع</td>
#       <td id="T_8d26d_row4_col1" class="data row4 col1" >شعجب</td>
#       <td id="T_8d26d_row4_col2" class="data row4 col2" >مفجوع</td>
#       <td id="T_8d26d_row4_col3" class="data row4 col3" >أذهل</td>
#       <td id="T_8d26d_row4_col4" class="data row4 col4" >آهل</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8d26d_row5_col0" class="data row5 col0" >ءء</td>
#       <td id="T_8d26d_row5_col1" class="data row5 col1" >معجب</td>
#       <td id="T_8d26d_row5_col2" class="data row5 col2" >تلألأ</td>
#       <td id="T_8d26d_row5_col3" class="data row5 col3" >أمآرس</td>
#       <td id="T_8d26d_row5_col4" class="data row5 col4" >مذهل</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8d26d_row6_col0" class="data row6 col0" >ييسونغ</td>
#       <td id="T_8d26d_row6_col1" class="data row6 col1" >أعجب</td>
#       <td id="T_8d26d_row6_col2" class="data row6 col2" >أثرثر</td>
#       <td id="T_8d26d_row6_col3" class="data row6 col3" >إشتياق</td>
#       <td id="T_8d26d_row6_col4" class="data row6 col4" >منفى</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8d26d_row7_col0" class="data row7 col0" >يفهمونها</td>
#       <td id="T_8d26d_row7_col1" class="data row7 col1" >عج</td>
#       <td id="T_8d26d_row7_col2" class="data row7 col2" >ى</td>
#       <td id="T_8d26d_row7_col3" class="data row7 col3" >شآحا</td>
#       <td id="T_8d26d_row7_col4" class="data row7 col4" >ذهن</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8d26d_row8_col0" class="data row8 col0" >فئ</td>
#       <td id="T_8d26d_row8_col1" class="data row8 col1" >فواعجبا</td>
#       <td id="T_8d26d_row8_col2" class="data row8 col2" >غمز</td>
#       <td id="T_8d26d_row8_col3" class="data row8 col3" >ترنم</td>
#       <td id="T_8d26d_row8_col4" class="data row8 col4" >أيقظ</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8d26d_row9_col0" class="data row9 col0" >مغثوث</td>
#       <td id="T_8d26d_row9_col1" class="data row9 col1" >جب</td>
#       <td id="T_8d26d_row9_col2" class="data row9 col2" >هلوسة</td>
#       <td id="T_8d26d_row9_col3" class="data row9 col3" >اصدقائك</td>
#       <td id="T_8d26d_row9_col4" class="data row9 col4" >وأوسطهآ</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8d26d_row10_col0" class="data row10 col0" >رآي</td>
#       <td id="T_8d26d_row10_col1" class="data row10 col1" >اتعجب</td>
#       <td id="T_8d26d_row10_col2" class="data row10 col2" >خنق</td>
#       <td id="T_8d26d_row10_col3" class="data row10 col3" >دهشة</td>
#       <td id="T_8d26d_row10_col4" class="data row10 col4" >آم</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8d26d_row11_col0" class="data row11 col0" >ى</td>
#       <td id="T_8d26d_row11_col1" class="data row11 col1" >مايعجب</td>
#       <td id="T_8d26d_row11_col2" class="data row11 col2" >يؤم</td>
#       <td id="T_8d26d_row11_col3" class="data row11 col3" >جدااا</td>
#       <td id="T_8d26d_row11_col4" class="data row11 col4" >أصوآت</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8d26d_row12_col0" class="data row12 col0" >اصابعك</td>
#       <td id="T_8d26d_row12_col1" class="data row12 col1" >متعجب</td>
#       <td id="T_8d26d_row12_col2" class="data row12 col2" >مضيء</td>
#       <td id="T_8d26d_row12_col3" class="data row12 col3" >رداءة</td>
#       <td id="T_8d26d_row12_col4" class="data row12 col4" >ثلآث</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8d26d_row13_col0" class="data row13 col0" >فولفسبورغ</td>
#       <td id="T_8d26d_row13_col1" class="data row13 col1" >عجرم</td>
#       <td id="T_8d26d_row13_col2" class="data row13 col2" >قفز</td>
#       <td id="T_8d26d_row13_col3" class="data row13 col3" >شغف</td>
#       <td id="T_8d26d_row13_col4" class="data row13 col4" >ودآئمهآ</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8d26d_row14_col0" class="data row14 col0" >هائئئئئئئئها</td>
#       <td id="T_8d26d_row14_col1" class="data row14 col1" >عجاب</td>
#       <td id="T_8d26d_row14_col2" class="data row14 col2" >مفاارق</td>
#       <td id="T_8d26d_row14_col3" class="data row14 col3" >آنلكن</td>
#       <td id="T_8d26d_row14_col4" class="data row14 col4" >أخرهآ</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8d26d_row15_col0" class="data row15 col0" >لؤ</td>
#       <td id="T_8d26d_row15_col1" class="data row15 col1" >ووا</td>
#       <td id="T_8d26d_row15_col2" class="data row15 col2" >هففف</td>
#       <td id="T_8d26d_row15_col3" class="data row15 col3" >آهل</td>
#       <td id="T_8d26d_row15_col4" class="data row15 col4" >آلخلف</td>
#     </tr>
#     <tr>
#       <th id="T_8d26d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T
